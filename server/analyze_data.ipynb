# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mplfinance as mpf

# %%
df = pd.read_csv("new-data.csv")
print(f"Rows in CSV before reversing: {len(df)}")
missing_data = df.isnull().sum()
print(missing_data)
# Check the date range
print(f"Date range in the dataset: {df['timestamp'].min()} to {df['timestamp'].max()}")

df = df[::-1]  
df
# Out:
# Rows in CSV before reversing: 1365
# timestamp    0
# open         0
# high         0
# low          0
# close        0
# volume       0
# dtype: int64
# Date range in the dataset: 2025-03-27 04:00:00 to 2025-04-25 20:00:00
#                 timestamp     open    high     low     close   volume
# 1364  2025-03-27 04:00:00  568.000  568.89  567.23  567.7000    32117
# 1363  2025-03-27 04:15:00  567.700  568.46  567.70  568.4200    21858
# 1362  2025-03-27 04:30:00  568.480  568.95  568.42  568.6500    19445
# 1361  2025-03-27 04:45:00  568.650  569.32  568.26  569.3200     9714
# 1360  2025-03-27 05:00:00  569.330  569.37  568.87  569.1000     8300
# ...                   ...      ...     ...     ...       ...      ...
# 4     2025-04-25 19:00:00  551.140  551.15  550.85  551.0600     7862
# 3     2025-04-25 19:15:00  551.080  551.15  550.99  551.1090     8679
# 2     2025-04-25 19:30:00  551.125  551.17  550.70  551.1200     7317
# ...

# %%
# Step 1: Parse timestamp and keep as column
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values('timestamp').reset_index(drop=True)

# Step 2: Create a 'Date' column for grouping
df['Date'] = df['timestamp'].dt.date  # keep timestamp, extract date separately

# Step 3: Group to daily OHLC
daily = df.groupby('Date').agg({
    'high': 'max',
    'low': 'min',
    'open': 'first',
    'close': 'last'
})

# Step 4: Shift to get previous day's high/low
daily['Prev_High'] = daily['high'].shift(1)
daily['Prev_Low'] = daily['low'].shift(1)

daily.reset_index(inplace=True)

# Step 5: Merge previous day high/low into main df
df = df.merge(daily[['Date', 'Prev_High', 'Prev_Low']], on='Date', how='left')

# Step 6: Filter for rows with complete previous day data
filtered = df[df['Prev_High'].notnull() & df['Prev_Low'].notnull()]

# ✅ Final Output
print(filtered.head())
# Out:
#              timestamp    open    high     low   close  volume        Date  \
# 65 2025-03-28 04:00:00  566.48  566.88  564.42  565.14   28165  2025-03-28
# 66 2025-03-28 04:15:00  565.17  565.42  564.62  564.93    4390  2025-03-28
# 67 2025-03-28 04:30:00  564.83  565.48  564.55  565.47   15186  2025-03-28
# 68 2025-03-28 04:45:00  565.50  565.90  565.40  565.74    5012  2025-03-28
# 69 2025-03-28 05:00:00  565.83  566.03  565.70  566.00   10462  2025-03-28
#
#     Prev_High  Prev_Low
# 65    577.305   532.071
# 66    577.305   532.071
# 67    577.305   532.071
# 68    577.305   532.071
# 69    577.305   532.071

# %%
# Step 1: Convert to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Step 2: Make a temporary index for time-based operations
df = df.sort_values('timestamp').reset_index(drop=True)
df['datetime'] = df['timestamp']  # copy for indexing

# Step 3: Set datetime as index temporarily
df = df.set_index('datetime')

# Step 4: Localize to UTC only if tz-naive
if df.index.tz is None:
    df.index = df.index.tz_localize("UTC")

# Step 5: Convert to Eastern (NY time)
df.index = df.index.tz_convert("US/Eastern")

# Step 6: Create date column for grouping
df['Date'] = df.index.date

# Step 7: Filter London session: 3am–7am
london_session = df.between_time("03:00", "07:00")

# Step 8: Aggregate highs/lows per London session
london_range = london_session.groupby(london_session.index.date).agg({
    'high': 'max',
    'low': 'min'
}).rename(columns={'high': 'London_High', 'low': 'London_Low'})

# Step 9: Prepare to merge
london_range.reset_index(inplace=True)
london_range.rename(columns={'index': 'Date'}, inplace=True)

# Step 10: Merge into original df (which still has 'timestamp')
df = df.reset_index()  # bring datetime back to column, keep original timestamp too
df.drop(columns=['London_High', 'London_Low'], errors='ignore', inplace=True)
df = df.merge(london_range, on='Date', how='left')
df.drop(columns='Date', inplace=True)

df
# Out:
#                       datetime           timestamp     open    high     low  \
# 0    2025-03-27 00:00:00-04:00 2025-03-27 04:00:00  568.000  568.89  567.23
# 1    2025-03-27 00:15:00-04:00 2025-03-27 04:15:00  567.700  568.46  567.70
# 2    2025-03-27 00:30:00-04:00 2025-03-27 04:30:00  568.480  568.95  568.42
# 3    2025-03-27 00:45:00-04:00 2025-03-27 04:45:00  568.650  569.32  568.26
# 4    2025-03-27 01:00:00-04:00 2025-03-27 05:00:00  569.330  569.37  568.87
# ...                        ...                 ...      ...     ...     ...
# 1360 2025-04-25 15:00:00-04:00 2025-04-25 19:00:00  551.140  551.15  550.85
# 1361 2025-04-25 15:15:00-04:00 2025-04-25 19:15:00  551.080  551.15  550.99
# 1362 2025-04-25 15:30:00-04:00 2025-04-25 19:30:00  551.125  551.17  550.70
# 1363 2025-04-25 15:45:00-04:00 2025-04-25 19:45:00  551.100  551.25  551.06
# 1364 2025-04-25 16:00:00-04:00 2025-04-25 20:00:00  550.640  550.64  550.64
#
# ...

# %%
df.set_index('timestamp', inplace=True)

# Filter just the London session (3am–7am EST)
london_df = df.between_time("03:00", "07:00").copy()


# Check if London swept previous day highs/lows
london_df['swept_Prev_High'] = (london_df['high'] > london_df['Prev_High']) & (london_df['close'] < london_df['Prev_High'])
london_df['swept_Prev_Low']  = (london_df['low'] < london_df['Prev_Low']) & (london_df['close'] > london_df['Prev_Low'])

# Get daily open and compare with previous day range
df['Date'] = df.index.date
daily_open = df.groupby('Date')['open'].first()
prev_high = df.groupby('Date')['Prev_High'].first()
prev_low = df.groupby('Date')['Prev_Low'].first()

gap_up = daily_open > prev_high
gap_down = daily_open < prev_low


asia_df = df.between_time("00:00", "03:00")
asia_range = asia_df.groupby(asia_df.index.date).agg({'high': 'max', 'low': 'min'})

# Did London break Asia range?
london_high = london_df.groupby(london_df.index.date)['high'].max()
london_low = london_df.groupby(london_df.index.date)['low'].min()

# Align Asia range index with London session index
aligned_asia = asia_range.reindex(london_high.index)

# Check if London broke Asia range
broke_asia_high = london_high > aligned_asia['high']
broke_asia_low = london_low < aligned_asia['low']


# Simple bias direction: uptrend if London close > open
london_open = london_df.groupby(london_df.index.date)['open'].first()
london_close = london_df.groupby(london_df.index.date)['close'].last()
london_bias = (london_close > london_open).map({True: "up", False: "down"})


ny_open_df = df.between_time("09:30", "09:30").copy()
ny_open_df['Date'] = ny_open_df.index.date
ny_open_price = ny_open_df.groupby('Date')['open'].first()

ny_position_vs_london = ny_open_price - london_close  # positive = above London close


# Percent move in London session
london_momentum = (london_close - london_open) / london_open

# %%
sweeps = london_df.groupby(london_df.index.date)[['swept_Prev_High', 'swept_Prev_Low']].any()
df = df.merge(sweeps, left_on='Date', right_index=True, how='left')

# 2. Merge gap up/down
gap_df = pd.DataFrame({
    'gap_up': gap_up,
    'gap_down': gap_down
})
df = df.merge(gap_df, left_on='Date', right_index=True, how='left')

# 3. Merge Asia range breakouts
asia_break = pd.DataFrame({
    'broke_Asia_High': broke_asia_high,
    'broke_Asia_Low': broke_asia_low
})
df = df.merge(asia_break, left_on='Date', right_index=True, how='left')

# 4. Merge London bias
df = df.merge(london_bias.rename('London_Bias'), left_on='Date', right_index=True, how='left')

# 5. Merge NY open position
df = df.merge(ny_position_vs_london.rename('NY_Position_vs_London'), left_on='Date', right_index=True, how='left')

# 6. Merge London momentum
df = df.merge(london_momentum.rename('London_Momentum'), left_on='Date', right_index=True, how='left')

# Final cleanup
df.drop(columns='Date', inplace=True)

# %%
df.to_csv("engineered_data.csv", index=False)

df.head()
# Out:
#                                      datetime    open    high     low   close  \
# timestamp
# 2025-03-27 04:00:00 2025-03-27 00:00:00-04:00  568.00  568.89  567.23  567.70
# 2025-03-27 04:15:00 2025-03-27 00:15:00-04:00  567.70  568.46  567.70  568.42
# 2025-03-27 04:30:00 2025-03-27 00:30:00-04:00  568.48  568.95  568.42  568.65
# 2025-03-27 04:45:00 2025-03-27 00:45:00-04:00  568.65  569.32  568.26  569.32
# 2025-03-27 05:00:00 2025-03-27 01:00:00-04:00  569.33  569.37  568.87  569.10
#
#                      volume  Prev_High  Prev_Low  London_High  London_Low  \
# timestamp
# 2025-03-27 04:00:00   32117        NaN       NaN      577.305      564.94
# 2025-03-27 04:15:00   21858        NaN       NaN      577.305      564.94
# 2025-03-27 04:30:00   19445        NaN       NaN      577.305      564.94
# 2025-03-27 04:45:00    9714        NaN       NaN      577.305      564.94
# 2025-03-27 05:00:00    8300        NaN       NaN      577.305      564.94
#
# ...

# %%
# Load your data
D = pd.read_csv("engineered_data.csv")

# Step 1: Encode London Bias (categorical)
D['London_Bias'] = D['London_Bias'].map({'up': 1, 'down': 0})

# Step 2: Convert boolean-like features to int (after filling NAs)
bool_cols = [
    'swept_Prev_High', 'swept_Prev_Low', 'gap_up', 'gap_down',
    'broke_Asia_High', 'broke_Asia_Low'
]
D[bool_cols] = D[bool_cols].fillna(False).astype(int)

# Step 3: Drop rows where target logic would fail
D = D.dropna(subset=['close', 'London_High'])

# Step 4: Define the target (continuation if price breaks London high)
D['target'] = (D['close'] > D['London_High']).astype(int)

# Step 5: Fill numerical columns that may be missing
D['NY_Position_vs_London'] = D['NY_Position_vs_London'].fillna(0)
D['London_Momentum'] = D['London_Momentum'].fillna(0)

# Step 6: Drop rows where any other required feature is missing
required_cols = [
    'Prev_High', 'Prev_Low', 'London_High', 'London_Low',
    'NY_Position_vs_London', 'London_Momentum', 'London_Bias'
]
D = D.dropna(subset=required_cols).copy()

# ✅ Check results
print(f"✅ Rows after full cleaning: {len(D)}")
# Out:
# ✅ Rows after full cleaning: 1300

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# --- Features and target ---
features = [
    'open', 'high', 'low', 'Prev_High', 'Prev_Low',
    'swept_Prev_High', 'swept_Prev_Low', 'gap_up', 'gap_down',
    'broke_Asia_High', 'broke_Asia_Low', 'London_Bias',
    'NY_Position_vs_London', 'London_Momentum'
]
X = D[features]
y = D['target']

# --- Track indices before split ---
D = D.reset_index(drop=True)  # ensure sequential index
X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# --- Split ---
X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(
    X, y, X.index, test_size=0.2, random_state=42
)

# --- Train model ---
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# --- Predictions ---
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))

# --- Plot vs actual ---
D_test = D.loc[idx_test].copy()
D_test['prediction'] = y_pred

plt.figure(figsize=(14, 5))
plt.plot(D_test['datetime'], D_test['target'], label='Actual', marker='o')
plt.plot(D_test['datetime'], D_test['prediction'], label='Prediction', marker='x')
plt.title("Model Prediction vs Actual")
plt.xlabel("Datetime")
plt.ylabel("Target")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       229
#            1       0.94      0.97      0.95        31
#
#     accuracy                           0.99       260
#    macro avg       0.97      0.98      0.97       260
# weighted avg       0.99      0.99      0.99       260

# %%
print(D['target'].value_counts())
# Out:
# target
# 0    1148
# 1     152
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# Separate classes
df_majority = D[D['target'] == 0]
df_minority = D[D['target'] == 1]

# Upsample minority
df_minority_upsampled = resample(
    df_minority,
    replace=True,
    n_samples=len(df_majority),
    random_state=42
)

# Combine
D_balanced = pd.concat([df_majority, df_minority_upsampled])
D_balanced = D_balanced.sample(frac=1, random_state=42).reset_index(drop=True)


X = D_balanced[features]
y = D_balanced['target']


X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(
    X, y, X.index, test_size=0.2, random_state=42
)


# --- Train model ---
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# --- Predictions ---
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))

# --- Plot vs actual ---
D_test = D_balanced.loc[idx_test].copy()
D_test['prediction'] = y_pred


plt.figure(figsize=(14, 5))
plt.plot(D_test['datetime'], D_test['target'], label='Actual', marker='o')
plt.plot(D_test['datetime'], D_test['prediction'], label='Prediction', marker='x')
plt.title("Model Prediction vs Actual")
plt.xlabel("Datetime")
plt.ylabel("Target")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       224
#            1       0.99      1.00      0.99       236
#
#     accuracy                           0.99       460
#    macro avg       0.99      0.99      0.99       460
# weighted avg       0.99      0.99      0.99       460

# %%
# Account for bearish 
def classify_behavior(row):
    if row['close'] > row['London_High']:
        return 1
    elif row['close'] < row['London_Low']:
        return -1
    else:
        return 0

D['target'] = D.apply(classify_behavior, axis=1)

df_0 = D[D['target'] == 0]
df_1 = D[D['target'] == 1]
df_m1 = D[D['target'] == -1]

min_class_size = 50

df_0_bal = resample(df_0, replace=False, n_samples=min_class_size, random_state=42)
df_1_bal = resample(df_1, replace=True, n_samples=min_class_size, random_state=42)
df_m1_bal = resample(df_m1, replace=True, n_samples=min_class_size, random_state=42)


D_balanced = pd.concat([df_0_bal, df_1_bal, df_m1_bal]).sample(frac=1, random_state=42).reset_index(drop=True)

features = [
    'open', 'high', 'low', 'Prev_High', 'Prev_Low',
    'swept_Prev_High', 'swept_Prev_Low',
    'gap_up', 'gap_down',
    'broke_Asia_High', 'broke_Asia_Low',
    'London_Bias', 'NY_Position_vs_London', 'London_Momentum'
]
X = D_balanced[features]
y = D_balanced['target']

# --- Split ---
X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(
    X, y, D_balanced.index, test_size=0.4, random_state=42
)
# --- Model ---
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# --- Predict + report ---
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred, digits=4))

# --- Plot ---
D_test = D_balanced.loc[idx_test].copy()
D_test['prediction'] = y_pred

plt.figure(figsize=(14, 6))

# Plot actual and prediction as scatter for clarity
plt.scatter(D_test['datetime'], D_test['target'], label='Actual', color='royalblue', marker='o', s=60)
plt.scatter(D_test['datetime'], D_test['prediction'], label='Prediction', color='darkorange', marker='x', s=60)

plt.title("Model Prediction vs Actual (London Session Breakouts)", fontsize=14)
plt.xlabel("Datetime", fontsize=12)
plt.ylabel("Target\n-1 = Break Below\n0 = No Break\n1 = Break Above", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#           -1     0.9444    0.8500    0.8947        20
#            0     0.7222    0.6500    0.6842        20
#            1     0.7500    0.9000    0.8182        20
#
#     accuracy                         0.8000        60
#    macro avg     0.8056    0.8000    0.7990        60
# weighted avg     0.8056    0.8000    0.7990        60

# %%
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import pandas as pd

D = pd.read_csv('engineered_data.csv')

# --- Filter to 9:00 AM rows only ---
if 'datetime' in D.columns:
    D['datetime'] = pd.to_datetime(D['datetime'])
    D.set_index('datetime', inplace=True)

# 9:00 AM prediction points only
# Grab the last candle available *before* NY open (9:30 AM)
# --- Grab last row before 9:30 AM for each day ---
pre_ny = D.between_time("00:00", "09:29").copy()
pre_ny['date'] = pre_ny.index.date

# Select the latest (last) entry before NY open for each day
prediction_df = pre_ny.groupby('date').tail(1).copy()



# --- Get NY session behavior (9:30 AM–12:00 PM) to label target ---
D['date'] = D.index.date
ny_session = D.between_time("09:30", "12:00")
ny_highs = ny_session.groupby('date')['high'].max()
ny_lows = ny_session.groupby('date')['low'].min()

# Merge highs/lows from NY into the prediction frame
prediction_df['ny_high'] = prediction_df['date'].map(ny_highs)
prediction_df['ny_low'] = prediction_df['date'].map(ny_lows)

# --- Classify target: did price break London High or Low during NY session? ---
def classify_behavior(row):
    if pd.isna(row['London_High']) or pd.isna(row['London_Low']):
        return None
    if row['ny_high'] > row['London_High']:
        return 1  # Break above
    elif row['ny_low'] < row['London_Low']:
        return -1  # Break below
    else:
        return 0  # No break

# Apply the classify_behavior function
prediction_df['target'] = prediction_df.apply(classify_behavior, axis=1)

# Drop rows with None or invalid target values
prediction_df = prediction_df.dropna(subset=['target'])

# Ensure that the target is numeric
prediction_df['target'] = pd.to_numeric(prediction_df['target'], errors='coerce')

# Drop rows where target is NaN (if conversion failed)
prediction_df = prediction_df.dropna(subset=['target'])

# --- Check the target column after conversion ---
print(prediction_df['target'].value_counts())

# --- Continue with the rest of your analysis ---


# --- Balance the data ---
df_0 = prediction_df[prediction_df['target'] == 0]
df_1 = prediction_df[prediction_df['target'] == 1]
df_m1 = prediction_df[prediction_df['target'] == -1]
# Print counts to debug
print("Class counts after 9:00AM filtering:")
print(f"  -1 (break below): {len(df_m1)}")
print(f"   0 (no break):     {len(df_0)}")
print(f"   1 (break above):  {len(df_1)}")

# Proceed only if at least 2 classes exist
available_classes = [cls for cls, df in zip([-1, 0, 1], [df_m1, df_0, df_1]) if len(df) > 0]

if len(available_classes) < 2:
    raise ValueError("Not enough diversity in target classes after 9:00AM filtering to train a model.")

print(f"⚠️ Only using classes: {available_classes}")

# Resample only the available ones
resampled = []
for cls, df in zip([-1, 0, 1], [df_m1, df_0, df_1]):
    if len(df) > 0:
        resampled_df = resample(df, replace=True, n_samples=10, random_state=42)
        resampled.append(resampled_df)

D_balanced = pd.concat(resampled).sample(frac=1, random_state=42).reset_index()



# Safe balancing
min_class_size = min(len(df_0), len(df_1), len(df_m1))

# Avoid using "replace=True" for small data sets, this could be causing class imbalances.
df_0_bal = resample(df_0, replace=False, n_samples=min_class_size, random_state=42) if len(df_0) > 0 else df_0
df_1_bal = resample(df_1, replace=False, n_samples=min_class_size, random_state=42) if len(df_1) > 0 else df_1
df_m1_bal = resample(df_m1, replace=False, n_samples=min_class_size, random_state=42) if len(df_m1) > 0 else df_m1

# Concatenate balanced data, keeping more original samples
D_balanced = pd.concat([df_0_bal, df_1_bal, df_m1_bal]).sample(frac=1, random_state=42).reset_index(drop=True)

# --- Check class counts after balancing ---
print("Class counts after balancing:")
print(f"  -1 (break below): {len(df_m1_bal)}")
print(f"   0 (no break):     {len(df_0_bal)}")
print(f"   1 (break above):  {len(df_1_bal)}")

# --- Features + Labels ---
features = [
    'open', 'high', 'low', 'Prev_High', 'Prev_Low',
    'swept_Prev_High', 'swept_Prev_Low',
    'gap_up', 'gap_down',
    'broke_Asia_High', 'broke_Asia_Low',
    'London_Bias', 'NY_Position_vs_London', 'London_Momentum'
]
X = D_balanced[features]
y = D_balanced['target']

# --- Split ---
X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(
    X, y, D_balanced.index, test_size=0.4, random_state=42
)

# --- Train ---
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# --- Predict ---
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred, digits=4))

# --- Plot ---
D_test = D_balanced.loc[idx_test].copy()
D_test['prediction'] = y_pred

plt.figure(figsize=(14, 6))
plt.scatter(D_test['datetime'], D_test['target'], label='Actual', color='royalblue', marker='o', s=60)
plt.scatter(D_test['datetime'], D_test['prediction'], label='Prediction', color='darkorange', marker='x', s=60)

plt.title("Model Prediction vs Actual (London Session Breakouts)", fontsize=14)
plt.xlabel("Datetime", fontsize=12)
plt.ylabel("Target\n-1 = Break Below\n0 = No Break\n1 = Break Above", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# target
#  1    11
#  0     5
# -1     5
# Name: count, dtype: int64
# Class counts after 9:00AM filtering:
#   -1 (break below): 5
#    0 (no break):     5
#    1 (break above):  11
# ⚠️ Only using classes: [-1, 0, 1]
# Class counts after balancing:
#   -1 (break below): 5
#    0 (no break):     5
#    1 (break above):  5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 129
#     127 # --- Train ---
#     128 model = RandomForestClassifier(n_estimators=100, random_state=42)
# --> 129 model.fit(X_train, y_train)
#     131 # --- Predict ---
#     132 y_pred = model.predict(X_test)
#
# File ~/Documents/Snake/Mobile-ddev/DayTradingSupportTool/server/.venv/lib/python3.11/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
# ...

# %%
import pandas as pd

# Load the data
df = pd.read_csv("engineered_data.csv", parse_dates=["datetime"])
df.set_index("datetime", inplace=True)

# Re-filter to broaden the sweep timeframe to before 12:00 PM
df = df.copy()
df["date"] = df.index.date
df["hour"] = df.index.hour

# Detect sweeps before 12 PM (previous hourly high or low)
df["swept_hourly_high"] = (df["high"] > df["Prev_High"]) & (df["hour"] < 12)
df["swept_hourly_low"] = (df["low"] < df["Prev_Low"]) & (df["hour"] < 12)

# Find the sweep times
sweeps = df[(df["swept_hourly_high"] | df["swept_hourly_low"])].copy()
sweeps["sweep_type"] = sweeps.apply(
    lambda row: 1 if row["swept_hourly_high"] else (-1 if row["swept_hourly_low"] else 0),
    axis=1
)

# Look 1 hour ahead and determine if price continued or reversed
results = []
for idx, row in sweeps.iterrows():
    lookahead_time = idx + pd.Timedelta(hours=1)
    if lookahead_time in df.index:
        after_row = df.loc[lookahead_time]
        if row["sweep_type"] == 1:  # Swept high
            outcome = 1 if after_row["close"] > row["close"] else -1
        elif row["sweep_type"] == -1:  # Swept low
            outcome = 1 if after_row["close"] < row["close"] else -1
        else:
            outcome = 0
        results.append({
            "datetime": idx,
            "sweep_type": row["sweep_type"],
            "outcome": outcome,
            "open": row["open"],
            "high": row["high"],
            "low": row["low"],
            "close": row["close"],
            "Prev_High": row["Prev_High"],
            "Prev_Low": row["Prev_Low"],
            "London_High": row["London_High"],
            "London_Low": row["London_Low"],
            "swept_Prev_High": row["swept_Prev_High"],
            "swept_Prev_Low": row["swept_Prev_Low"],
            "gap_up": row["gap_up"],
            "gap_down": row["gap_down"],
            "broke_Asia_High": row["broke_Asia_High"],
            "broke_Asia_Low": row["broke_Asia_Low"],
            "London_Bias": row["London_Bias"],
            "NY_Position_vs_London": row["NY_Position_vs_London"],
            "London_Momentum": row["London_Momentum"]
        })

sweep_df = pd.DataFrame(results)
sweep_df.head()
# Out:
#                    datetime  sweep_type  outcome    open    high      low  \
# 0 2025-04-04 03:15:00-04:00          -1       -1  521.67  522.75  517.210
# 1 2025-04-04 03:30:00-04:00          -1       -1  517.50  520.80  515.880
# 2 2025-04-04 03:45:00-04:00          -1       -1  517.90  523.27  517.830
# 3 2025-04-04 04:00:00-04:00          -1       -1  522.02  537.07  515.997
# 4 2025-04-04 05:30:00-04:00          -1        1  523.67  525.87  519.150
#
#     close  Prev_High  Prev_Low  London_High  London_Low  swept_Prev_High  \
# 0  517.60   564.9647  519.8712       537.07      510.05            False
# 1  517.90   564.9647  519.8712       537.07      510.05            False
# 2  523.01   564.9647  519.8712       537.07      510.05            False
# 3  522.66   564.9647  519.8712       537.07      510.05            False
# 4  520.22   564.9647  519.8712       537.07      510.05            False
#
#    swept_Prev_Low  gap_up  gap_down  broke_Asia_High  broke_Asia_Low  \
# ...
